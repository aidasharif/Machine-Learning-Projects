# %% [raw]
# # CS6140 Assignments
#
# **Instructions**
# 1. In each assignment cell, look for the block:
#  ```
#   #BEGIN YOUR CODE
#   raise NotImplementedError.new()
#   #END YOUR CODE
#  ```
# 1. Replace this block with your solution.
# 1. Test your solution by running the cells following your block (indicated by ##TEST##)
# 1. Click the "Validate" button above to validate the work.
#
# **Notes**
# * You may add other cells and functions as needed
# * Keep all code in the same notebook
# * In order to receive credit, code must "Validate" on the JupyterHub server
#
# ---

# %% [markdown]
# # Assignment 4: Linear Models (2)
#
#
# In this exercise, we will transform our gradient descent algorithm into stochastic gradent descent. We will then implement linear regression and logistic regression. Finally, we will run these models on a real-world dataset.

# %%
require './assignment_lib'
# Out:
# false

# %%
require './LinearModels'
# Out:
# LoadError: cannot load such file -- daru
# /Users/aidasharifrohani/.rbenv/versions/2.4.1/lib/ruby/2.4.0/rubygems/core_ext/kernel_require.rb:55:in `require'
# /Users/aidasharifrohani/.rbenv/versions/2.4.1/lib/ruby/2.4.0/rubygems/core_ext/kernel_require.rb:55:in `require'
# /Users/aidasharifrohani/Desktop/personal_git/Machine-Learning-Projects/LinearModels/LinearModels.rb:2:in `<top (required)>'
# /Users/aidasharifrohani/.rbenv/versions/2.4.1/lib/ruby/2.4.0/rubygems/core_ext/kernel_require.rb:55:in `require'
# /Users/aidasharifrohani/.rbenv/versions/2.4.1/lib/ruby/2.4.0/rubygems/core_ext/kernel_require.rb:55:in `require'
# <main>:in `<main>'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/backend.rb:44:in `eval'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/backend.rb:44:in `eval'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/backend.rb:12:in `eval'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/kernel.rb:90:in `execute_request'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/kernel.rb:49:in `dispatch'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/kernel.rb:38:in `run'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/command.rb:110:in `run_kernel'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/command.rb:40:in `run'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/bin/iruby:5:in `<top (required)>'
# /System/Volumes/Data/Users/aidasharifrohani/.gem/bin/iruby:22:in `load'
# /System/Volumes/Data/Users/aidasharifrohani/.gem/bin/iruby:22:in `<main>'

# %% [markdown]
# ## Question 1.1 (10 points)
#
# Transform your batch gradient descent into a stochastic gradient descent algorithm. Using a class here allows the SGD algorithm to maintain state, such as learning rate and weights. Test your algorithm on the coin dataset and Binomial model you coded in Assignment 3. Plot the likelihood measured for each batch of 100 examples on one pass of the dataset.
#
# We will implement mini-batch SGD. Therefore you will not have to alter your Binomial Model.
#
# Stochasic gradient descent requires a learning rate that decreases with each iteration. Use the following learning rate:
#
# ## $\eta = \frac{\eta_{0}}{\sqrt{t}}$
#
# where $\eta_{0}$ is the initial learning rate and $t$ is the number of mini-batch iterations.
#
# The ```update``` function updates the member variable ```@weights``` and potentially other parameters based on the dataset. For SGD, now ```x``` is not the full dataset but a batch of examples. It needs to call the ```grad``` function in the objective, and there is no return value.
#
#
# Example lines with ```__note__``` indicate placeholders for code:
#
# ```ruby
# def update x
#     @objective.grad(x, @weights)
#     learning_rate = __calculate_learning_rate__
#     __update_each_weight__ #based on the update formula and the learning rate
#     __don_t_forget_to_call_adjust__
# end
# ```

# %%
class StochasticGradientDescent
  attr_reader :weights
  attr_reader :objective
  def initialize obj, w_0, lr = 0.01
    @objective = obj
    @weights = w_0
    @n = 1.0
    @lr = lr
  end
  def update x    
    dw=@objective.grad(x, @weights)
    @weights.each do |key1, array1|
      dw.each do |key2, array2|
        if key1==key2 then
          @weights[key1]=array1-dw[key2]*(@lr/(@n**0.5)).to_f
        end
      end
    end
    @n+=1

  end
    
  def adjust w
    w.each do |key,array|
      w[key] = [[0.001, w[key]].max, 0.999].min
    end
    return w
  end
end
# Out:
# :adjust

# %%
### TEST ###
# Demonstrates that weights are stored in the gradient function. 
# This is included in the provided code, so just an example of how to use SGD
class EmptyObjective
  def func x, w; end
  def grad x, w; end
  def adjust w; end
end

t0_w = {"0" => 1.23, "1" => 4.56}
t0_obj = EmptyObjective.new
t0_sgd = StochasticGradientDescent.new t0_obj, t0_w, 0.25

puts t0_sgd.weights
assert_in_delta 1.23, t0_sgd.weights["0"], 1e-2
# Out:
# {"0"=>1.23, "1"=>4.56}
# NoMethodError: undefined method `assert_in_delta' for main:Object
# <main>:14:in `<main>'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/backend.rb:44:in `eval'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/backend.rb:44:in `eval'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/backend.rb:12:in `eval'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/kernel.rb:90:in `execute_request'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/kernel.rb:49:in `dispatch'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/kernel.rb:38:in `run'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/command.rb:110:in `run_kernel'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/command.rb:40:in `run'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/bin/iruby:5:in `<top (required)>'
# /System/Volumes/Data/Users/aidasharifrohani/.gem/bin/iruby:22:in `load'
# /System/Volumes/Data/Users/aidasharifrohani/.gem/bin/iruby:22:in `<main>'

# %%
### TEST ###
# Perform a single update to the weights and see that the objective function value is different.
# This is a no-data objective, so we are not providing any data, so our batch of examples is empty.
class ParabolaObjective
  def func x, w
    0.5 * ((w["x0"] - 1) ** 2.0 + (w["z1"] - 2) ** 2.0)
  end
  def grad x, w
    dw = {"x0" => (w["x0"] - 1), "z1" => (w["z1"] - 2)}
  end
  def adjust w
  end
end

def test_1_1_0
  w = {"x0" => 0.0, "z1" => 0.0}
  learning_rate = 0.25
  obj = ParabolaObjective.new
  sgd = StochasticGradientDescent.new obj, w, learning_rate
  batch_of_examples = []
  
  lik_0 = obj.func(batch_of_examples, sgd.weights)
  puts lik_0
  
  #Calculate objective for initial weights
  assert_in_delta 0.0, sgd.weights["x0"], 1e-2
  assert_in_delta 2.5, lik_0, 1e-2

  #Update weights
  sgd.update(batch_of_examples)
  puts sgd.weights
  
  #Now, objective function is different for the newly updated weights
  lik_1 = obj.func(batch_of_examples, sgd.weights)
  puts lik_1
  
  assert_in_delta 0.25, sgd.weights["x0"], 1e-2
  assert_in_delta 1.40625, lik_1, 1e-2
end

test_1_1_0()
# Out:
# 2.5
# NoMethodError: undefined method `assert_in_delta' for main:Object
# <main>:25:in `test_1_1_0'
# <main>:40:in `<main>'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/backend.rb:44:in `eval'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/backend.rb:44:in `eval'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/backend.rb:12:in `eval'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/kernel.rb:90:in `execute_request'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/kernel.rb:49:in `dispatch'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/kernel.rb:38:in `run'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/command.rb:110:in `run_kernel'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/lib/iruby/command.rb:40:in `run'
# /Users/aidasharifrohani/.gem/gems/iruby-0.4.0/bin/iruby:5:in `<top (required)>'
# /System/Volumes/Data/Users/aidasharifrohani/.gem/bin/iruby:22:in `load'
# /System/Volumes/Data/Users/aidasharifrohani/.gem/bin/iruby:22:in `<main>'

# %%
### TEST ###
# Testing on a known objective. Repeat SGD for 1000 iterations and expect to converge to correct solution.

def test_1_1_1
  w = {"x0" => 0.0, "z1" => 0.0}
  learning_rate = 0.25
  obj = ParabolaObjective.new
  sgd = StochasticGradientDescent.new obj, w, learning_rate
  batch_of_examples = []

  puts batch_of_examples
  lik = 1.0
  100.times do 
    sgd.update(batch_of_examples)
    lik = obj.func(batch_of_examples, sgd.weights)

  end

  assert_true(lik < 0.1, "SGD converges with simple objective")
  assert_in_delta 1.0, sgd.weights["x0"], 0.1, "Weight 0 expected to be 1.0"
  assert_in_delta 2.0, sgd.weights["z1"], 0.1, "Weight 1 expected to be 2.0"
end

test_1_1_1()
# Out:
# []

# %%
### TEST ###
# Testing on a known objective. Repeat SGD for 1000 iterations and expect to converge to correct solution.

def test_1_1_1
  w = {"x0" => 0.0, "z1" => 0.0}
  learning_rate = 0.25
  obj = ParabolaObjective.new
  sgd = StochasticGradientDescent.new obj, w, learning_rate
  batch_of_examples = []

  lik = 1.0
  1000.times do 
    sgd.update(batch_of_examples)
    lik = obj.func(batch_of_examples, sgd.weights)
  end

  assert_true(lik < 0.1, "SGD converges with simple objective")
  assert_in_delta 1.0, sgd.weights["x0"], 0.1, "Weight 0 expected to be 1.0"
  assert_in_delta 2.0, sgd.weights["z1"], 0.1, "Weight 1 expected to be 2.0"
end

test_1_1_1()

# %% [markdown]
# ## Begin Question 2.1 (10 points)
#
# Implement linear regression as an objective function for use with stochastic gradient descent. First, we will implement the predict function. For a weight vector, $w$ and a single ```Row``` with features, $x$, implement:
#
# ### $f(w,x) = w^T x$
#
#
# Note that in the formula above ```x``` is the ```features``` key in the example. Check out the ```fetch``` and ```has_key?``` methods in ruby.

# %%
class LinearRegressionModel  
  def predict example, weights

    sum=0
    if example["features"].size==0
      return 0
    end
    example["features"].each do |key1, array1|
      weights.each do |key2, array2|
        if key1==key2 then
          sum+=array1*array2
        end
      end
    end

    return sum

  end
end
# Out:
# :predict

# %%
### TEST ###aida
# Tests that function can predict when all keys are found both vectors
def test_2_1_0
  lr = LinearRegressionModel.new
  example = {"features"=>{"bias"=>1.0}, "label"=>1.0}
  weights = {"bias"=>0.5}
  
  assert_in_delta 6.0, lr.predict(example, weights), 1e-6
end
# Out:
# :test_2_1_0

# %%
### TEST ###
# Tests that function can predict when all keys are found both vectors
def test_2_1_0
  lr = LinearRegressionModel.new
  example = {"features" => {"a" => 2.0}}
  weights = {"a" => 3.0}
  
  assert_in_delta 6.0, lr.predict(example, weights), 1e-6
end
# Out:
# :test_2_1_0

# %%
### TEST ###
# Tests that function can predict even when weights are missing
def test_2_1_1
  lr = LinearRegressionModel.new
  
  puts "Handles empty weights"
  empty_example = {"features" => {}}
  empty_weights = {}  
  assert_equal 0.0, lr.predict(empty_example, empty_weights)
  
  puts "Handles weights not in features"
  weights_without_a = {"a" => 0.0, "b" => 1.0}
  example_a = {"features" => {"a" => 1.0}}
  assert_equal 0.0, lr.predict(example_a, weights_without_a)
  
  puts "Handles features not in weights"
  example_bc = {"features" => {"b" => 7.2, "c" => 2.5}}
  assert_in_delta 7.2, lr.predict(example_bc, weights_without_a), 1e-2
end

test_2_1_1()
# Out:
# Handles empty weights
# Handles weights not in features
# Handles features not in weights

# %% [markdown]
# ## Begin Question 2.2 (10 points)
#
# Continuing the implementation, implement the $L_2$ loss, which applies to a mini-batch of $n$ points. Use the ```predict``` function you implemented earlier.
#
# ### $L(w,X) = \frac{1}{n} \sum_{i} \frac{1}{2} \left(f(w,x_i) - y_i\right) ^ 2$
#
# where $x_i$ is the ```features``` of the example, $y_i$ is the ```label``` of the example, and $n$ is the number of examples in the batch.

# %%
class LinearRegressionModel
  def func examples, w

    sum=0
    model2 = LinearRegressionModel.new
    examples.each do |key1, array1|
      sum+=0.5*((model2.predict(key1,w)-key1["label"])**2)
    end
    
    return (sum/examples.size)

  end
  ## Adjusts the parameter to be within the allowable range
  def adjust w
  end
end
# Out:
# :adjust

# %%
### TEST ###aida
# Use the coin dataset to measure the loss for a single-example batch.
def test_2_2_0
  #Use a fixed seed so that the coin dataset returns the same value each time
  dataset = coin_dataset(100)
  examples = dataset["data"]
  assert_equal 100, examples.size
  
  # Batch of size 1 from a dataset of 100 examples
  batch = examples[0,1]
  puts batch  
  assert_equal 1, batch.size
  
  #Start with mu parameter 0.1, denoted by bias
  model = LinearRegressionModel.new
  weights_mu_0_1 = {"bias" => 0.5}
  
  #Calculate the squared loss
  f = model.func batch, weights_mu_0_1
  puts f
  assert_in_delta 0.125, f, 0.050, "Expected loss within [250, 350]"
end

test_2_2_0()
# Out:
# [{"features"=>{"bias"=>1.0}, "label"=>1.0}]
# 0.125

# %%
### TEST ###
# Use the coin dataset to measure the loss for a single-example batch.
def test_2_2_0
  #Use a fixed seed so that the coin dataset returns the same value each time
  dataset = coin_dataset(100)
  examples = dataset["data"]
  assert_equal 100, examples.size
  
  # Batch of size 1 from a dataset of 100 examples
  batch = examples[0,1]
  puts batch  
  assert_equal 1, batch.size
  
  #Start with mu parameter 0.1, denoted by bias
  model = LinearRegressionModel.new
  weights_mu_0_1 = {"bias" => 0.5}
  
  #Calculate the squared loss
  f = model.func batch, weights_mu_0_1
  puts f
  assert_in_delta 0.125, f, 0.050, "Expected loss within [250, 350]"
end

test_2_2_0()
# Out:
# [{"features"=>{"bias"=>1.0}, "label"=>0.0}]
# 0.125

# %%
### TEST ###
# Use the coin dataset
t22_data = coin_dataset(1000)

t22_model = LinearRegressionModel.new
t22_w = Hash.new
t22_w["bias"] = 0.1

t22_f = t22_model.func t22_data["data"], t22_w
assert_in_delta 0.300, t22_f, 0.050, "Expected loss within [250, 350]"

t22_w["bias"] = 0.77
t22_f = t22_model.func t22_data["data"], t22_w
assert_in_delta 0.090, t22_f, 0.050, "Expected loss for a closer guess to be within [40, 140]"

# %% [markdown]
# ## Begin Question 2.3 (10 points)
#
# Continuing the implementation of linear regression, now implement the gradient function. This returns a gradient vector for the mini-batch of $n$ points.
#
# Note that the gradient for a batch is the average gradient for all examples in the batch, which is why there is an initializer for the ```gradient``` hash.

# %%
class LinearRegressionModel
  def grad examples, weights
    gradient = Hash.new {|h,k| h[k] = 0.0}
    
    sum=0
    model2 = LinearRegressionModel.new
    puts examples 
    examples.each do |key1, array1|
      sum+=(model2.predict(key1,weights)-key1["label"])*key1["features"]["bias"]
    end
    
    gradient["bias"]=(sum/examples.size)

    return gradient
  end
end
# Out:
# :grad

# %%
### TEST ###
# Calculate the gradient update on a batch of 5 examples

def test_2_3_0 
  #Use a fixed seed so the gradient value comes out the same
  srand 1295187568912756074856
  dataset = coin_dataset(1000)
  model = LinearRegressionModel.new
  
  #Batch of size 5 of 1000
  examples = dataset["data"]
  batch = examples[0,5]
  puts "Batch:"  
  puts batch
  assert_equal 5, batch.size
  
  #Initialize weights with mu value represented by bias
  weights = Hash.new
  weights["bias"] = 0.1

  gradient = model.grad batch, weights
  puts "Gradient:"
  puts gradient
  assert_in_delta -0.5, gradient["bias"], 0.2, "Expected loss within [-0.49, -0.89]"
end

test_2_3_0()
# Out:
# Batch:
# [{"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}]
# Gradient:
# {"bias"=>-0.5}

# %%
### TEST ###

t23_data = coin_dataset(1000)
t23_model = LinearRegressionModel.new
t23_w = Hash.new
t23_w["bias"] = 0.1

t23_g = t23_model.grad t23_data["data"], t23_w
assert_in_delta -0.69, t23_g["bias"], 0.2, "Expected loss within [-0.49, -0.89]"

t23_w["bias"] = 0.77
t23_g = t23_model.grad t23_data["data"], t23_w
assert_in_delta 0.0, t23_g["bias"], 0.1, "Expected loss for a better guess to be within [-0.1, 0.1]"
# Out:
# [{"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0},  ...
# [{"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0},  ...

# %% [markdown]
# ## Question 2.4 (10 points)
#
# Putting the previous steps together, use your ```StochasticGradientDecent``` to run linear regression for 10 passes (epochs) over the Coin Dataset, each pass with a mini-batch of size 20. Tune the learning rate, ```lr```, so that the model converges well. Assume that ```obj``` is an instance of ```LinearRegressionModel```, and ```w``` is an initial weight vector.
#
# Track the number of batches in the ```iters``` array and the loss in the ```losses``` array.

# %%
def train_coin_sgd(obj, w, dataset)
  i = 0
  iters = []
  losses = []
  lr=0.4

  sgd = StochasticGradientDescent.new obj, w, lr
  model = LinearRegressionModel.new

  for j in 0..10 do
    for i in 0..19 do
      batch_of_examples=[]
      batch_of_examples=dataset["data"][(i*50)...((i+1)*50-1)]
      sgd.update(batch_of_examples)
    end
      losses << model.func(batch_of_examples,w)
      iters << j

  end
  
  return [sgd, iters, losses]
end
# Out:
# :train_coin_sgd

# %%
### TEST ###
t24_data = coin_dataset(1000)
t24_model = LinearRegressionModel.new
t24_w = Hash.new
t24_w["bias"] = 0.1

t24_trainer, t24_iter, t24_losses = train_coin_sgd t24_model, t24_w, t24_data

assert_true t24_w.has_key?("bias")
assert_in_delta 0.77, t24_w["bias"], 0.1, "Expected weight for 'bias'  [0.67, 0.87]"
t24_cum_loss = 0.0
t24_losses.each_index {|i| t24_cum_loss += t24_losses[i]; t24_losses[i] = t24_cum_loss / (t24_iter[i] + 1)}
Daru::DataFrame.new({x: t24_iter, y: t24_losses}).plot(type: :line, x: :x, y: :y) do |plot, diagram|
  plot.x_label "Batches"
  plot.y_label "Cumulative Loss"
end
# Out:
# [{"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# ...
# [{"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}]
# [{"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>0.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}, {"features"=>{"bias"=>1.0}, "label"=>1.0}]
# #<Nyaplot::Plot:0x0000000001a754d0 @properties={:diagrams=>[#<Nyaplot::Diagram:0x0000000001b0ded8 @properties={:type=>:line, :options=>{:x=>:x, :y=>:y}, :data=>"53e88df6-9f59-4a9a-9af2-f4a024c958ca"}, @xrange=[0, 10], @yrange=[0.06432586047703087, 0.06610033992327628]>], :options=>{:x_label=>"Batches", :y_label=>"Cumulative Loss", :zoom=>true, :width=>700, :xrange=>[0, 10], :yrange=>[0.06432586047703087, 0.06610033992327628]}}>

# %% [markdown]
# ## Question 3.1 (10 points)
#
# Implement Logistic Regression, following much the same process as with linear regression. The prediction function returns a value:
#
# ### $f(x,w) = \frac {1}{1 + \exp \left( -w^T x \right) } $

# %%
class LogisticRegressionModel
  def predict row, w
    sum=0.0
    if w.size==0
      row["features"].each do |key1, array1|
          w[key1]= w[key1]
      end
    end
      
    if row["features"].size==0
      return 0
    end
    row["features"].each do |key1, array1|
      w.each do |key2, array2|
        if key1==key2 then
          sum+=array1*array2
        end
      end
    end

    return 1.0/(1.0+Math.exp(-sum))

  end
  
  def adjust w
    w
  end
end
# Out:
# :adjust

# %%
### TEST ###
t31_model = LogisticRegressionModel.new
def t31_f(a: 0.0, b: 0.0)
  row = {"features" => {"a" => a, "b" => b}}
end
def t31_w(a: 0.0, b: 0.0)
  w = {"a" => a, "b" => b}
end
assert_in_delta 0.5, t31_model.predict(t31_f(), t31_w()), 1e-6
assert_in_delta 0.2689, t31_model.predict(t31_f(a:1), t31_w(a:-1)), 1e-3
assert_in_delta 1.0, t31_model.predict(t31_f(a:1, b:1000), t31_w(a:-1, b: 0.1)), 1e-3

# %% [markdown]
# ## Question 3.2 (10 points)
#
# Implement log loss assuming that the y label is defined as: $y \in \left\{-1, 1\right\}$. Remember that the mini-batch loss is an expectation of the $n$ examples in the mini batch.

# %%
class LogisticRegressionModel
  def func data, w
    sum=0
    model2 = LogisticRegressionModel.new
    data.each do |key1, array1|
      sum+=key1["label"]*Math.log(model2.predict(key1,w))+(1-key1["label"])*Math.log(1-model2.predict(key1,w))
    end
    
    return ((-sum.to_f)/(data.size.to_f))
  end
  
end
# Out:
# :func

# %%
### TEST ###
t32_data = coin_dataset(1000)
t32_model = LogisticRegressionModel.new
t32_w = Hash.new {|h,k| h[k] = 0.1}
assert_in_delta 0.66, t32_model.func(t32_data["data"], t32_w), 0.2, "Expected LR.func in [460, 860]"

# %% [markdown]
# ## Question 3.3 (10 points)
#
# Calculate the gradient of the mini-batch log loss for each parameter $w$. This time, assume that $y \in \left\{0, 1\right\}$. Hint: This assumption should simplify the calculation.

# %%
class LogisticRegressionModel
  def grad data, w

    gradient={}
    sum=0
    model2 = LogisticRegressionModel.new
    
    data.each do |key1, array1|
      sum+=(key1["label"]-model2.predict(key1,w))*key1["features"]["bias"]
    end
    
    gradient["bias"]=-sum/data.size
    return gradient

  end
end
# Out:
# :grad

# %%
### TEST ###
t32_data = coin_dataset(1000)
t32_model = LogisticRegressionModel.new
t32_w = Hash.new {|h,k| h[k] = 0.1}
assert_in_delta 0.66, t32_model.func(t32_data["data"], t32_w), 0.2, "Expected LR.func in [460, 860]"
t32_g = t32_model.grad t32_data["data"], t32_w
assert_in_delta -0.26, t32_g["bias"], 0.1, "Expected LR.grad in [-0.36, -0.16]"

t32_w = Hash.new {|h,k| h[k] = 0.778}
t32_g = t32_model.grad t32_data["data"], t32_w
assert_in_delta -0.1, t32_g["bias"], 0.1, "Expected LR.grad for a closer value to be in [-0.2, -0.2]"

# %% [markdown]
# ## Question 4.1 (6 points)
#
# Let's train our new models on a familiar dataset, spambase. Let's run gradient descent for a few steps on this dataset. Observe that the learned weights after just gradient 2 steps are very large.

# %%
### Example ###
#Preview 2 lines from the Spambase dataset
spambase = read_sparse_data_from_csv "spambase"
spambase["data"].each {|r| r["features"]["bias"] = 1.0}
puts spambase["data"][0,2]

q41_model = LinearRegressionModel.new
q41_w = Hash.new {|h,k| h[k] = 0.0}
q41_w["bias"] = 1
q41_sgd = StochasticGradientDescent.new q41_model, q41_w, 0.1
2.times do
  q41_batch = spambase["data"].sample(10)
  q41_sgd.update q41_batch
end
puts q41_w
# Out:
# [{"features"=>{"word_freq_our"=>0.27, "word_freq_mail"=>0.83, "word_freq_you"=>0.27, "word_freq_your"=>0.27, "word_freq_font"=>8.58, "char_freq_["=>0.092, "char_freq_$"=>0.185, "char_freq_#"=>0.232, "capital_run_length_average"=>7.313, "capital_run_length_longest"=>99.0, "capital_run_length_total"=>607.0, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_your"=>0.9, "word_freq_george"=>0.9, "word_freq_data"=>0.9, "char_freq_["=>0.14, "capital_run_length_average"=>3.472, "capital_run_length_longest"=>28.0, "capital_run_length_total"=>125.0, "bias"=>1.0}, "label"=>0.0}]
# [{"features"=>{"word_freq_all"=>1.44, "word_freq_pm"=>2.89, "word_freq_meeting"=>2.89, "char_freq_("=>0.247, "capital_run_length_average"=>2.38, "capital_run_length_longest"=>8.0, "capital_run_length_total"=>50.0, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_all"=>1.06, "word_freq_over"=>0.35, "word_freq_will"=>2.13, "word_freq_business"=>0.71, "word_freq_you"=>0.71, "word_freq_hp"=>4.62, "word_freq_lab"=>0.35, "word_freq_labs"=>1.06, "word_freq_technology"=>0.35, "word_freq_1999"=>0.35, "word_freq_pm"=>0.35, "word_freq_original"=>0.35, "word_freq_re"=>0.71, "char_freq_("=>0.055, "char_freq_["=>0.055, "capital_run_length_average"=>2.239, "capital_run_length_longest"=>17.0, "capital_run_length_total"=>206.0, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_address"=>0.34, "word_freq_our"=>0.68, "word_freq_remove"=>0.68, "word_freq_mail"=>0.34, "word_freq_receive"=>0.34, "word_freq_free"=>0.34, "word_freq_email"=>1.36, "word_freq_you"=>3.42, "word_freq_your"=>2.73, "word_freq_hp"=>0.34, "word_freq_hpl"=>0.34, "word_freq_data"=>0.34, "char_freq_!"=>0.048, "char_freq_$"=>0.048, "capital_run_length_average"=>1.411, "capital_run_length_longest"=>15.0, "capital_run_length_total"=>96.0, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_make"=>0.09, "word_freq_all"=>0.09, "word_freq_our"=>0.39, "word_freq_over"=>0.09, "word_freq_remove"=>0.09, "word_freq_order"=>0.19, "word_freq_mail"=>0.29, "word_freq_receive"=>0.39, "word_freq_will"=>0.48, "word_freq_report"=>0.58, "word_freq_free"=>0.87, "word_freq_business"=>0.19, "word_freq_you"=>1.66, "word_freq_credit"=>4.1, "word_freq_your"=>1.66, "word_freq_000"=>0.39, "word_freq_money"=>0.19, "char_freq_("=>0.14, "char_freq_!"=>0.326, "char_freq_$"=>0.155, "capital_run_length_average"=>6.813, "capital_run_length_longest"=>494.0, "capital_run_length_total"=>1458.0, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_address"=>0.55, "word_freq_all"=>0.55, "word_freq_our"=>1.11, "word_freq_over"=>0.55, "word_freq_remove"=>2.23, "word_freq_mail"=>0.55, "word_freq_will"=>0.55, "word_freq_email"=>0.55, "word_freq_you"=>3.35, "word_freq_your"=>1.11, "word_freq_re"=>0.55, "char_freq_("=>0.159, "char_freq_!"=>0.479, "char_freq_#"=>0.079, "capital_run_length_average"=>16.739, "capital_run_length_longest"=>147.0, "capital_run_length_total"=>385.0, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_all"=>0.53, "word_freq_our"=>0.53, "word_freq_internet"=>0.53, "word_freq_mail"=>1.07, "word_freq_receive"=>1.07, "word_freq_free"=>1.07, "word_freq_you"=>3.76, "word_freq_your"=>1.07, "word_freq_re"=>0.53, "char_freq_("=>0.294, "char_freq_!"=>0.367, "capital_run_length_average"=>2.161, "capital_run_length_longest"=>21.0, "capital_run_length_total"=>67.0, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_address"=>1.96, "word_freq_all"=>0.98, "word_freq_remove"=>1.96, "word_freq_free"=>0.98, "word_freq_you"=>0.98, "word_freq_your"=>0.98, "word_freq_re"=>0.98, "char_freq_("=>0.168, "char_freq_!"=>1.011, "capital_run_length_average"=>2.888, "capital_run_length_longest"=>12.0, "capital_run_length_total"=>52.0, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_you"=>3.03, "word_freq_george"=>3.03, "word_freq_re"=>3.03, "capital_run_length_average"=>1.272, "capital_run_length_longest"=>4.0, "capital_run_length_total"=>14.0, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_make"=>0.24, "word_freq_all"=>0.49, "word_freq_mail"=>0.24, "word_freq_will"=>0.24, "word_freq_people"=>0.24, "word_freq_you"=>1.23, "word_freq_your"=>0.24, "word_freq_hp"=>0.24, "word_freq_hpl"=>0.24, "word_freq_650"=>0.49, "word_freq_labs"=>0.24, "word_freq_85"=>0.49, "word_freq_table"=>0.74, "char_freq_;"=>0.029, "char_freq_("=>0.119, "char_freq_["=>0.119, "capital_run_length_average"=>3.574, "capital_run_length_longest"=>75.0, "capital_run_length_total"=>336.0, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_will"=>1.12, "word_freq_you"=>2.24, "word_freq_your"=>0.56, "word_freq_money"=>0.56, "word_freq ...
# [{"features"=>{"word_freq_all"=>0.42, "word_freq_people"=>0.21, "word_freq_free"=>0.21, "word_freq_email"=>0.21, "word_freq_you"=>2.14, "word_freq_your"=>0.42, "word_freq_cs"=>0.21, "word_freq_meeting"=>0.21, "word_freq_re"=>0.42, "word_freq_edu"=>0.21, "char_freq_("=>0.078, "char_freq_["=>0.039, "char_freq_!"=>0.039, "capital_run_length_average"=>1.292, "capital_run_length_longest"=>6.0, "capital_run_length_total"=>106.0, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_all"=>1.72, "word_freq_will"=>2.58, "word_freq_you"=>2.58, "word_freq_pm"=>0.86, "word_freq_cs"=>0.86, "word_freq_meeting"=>2.58, "word_freq_re"=>0.86, "char_freq_("=>0.303, "char_freq_!"=>0.91, "capital_run_length_average"=>2.171, "capital_run_length_longest"=>9.0, "capital_run_length_total"=>76.0, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_make"=>0.56, "word_freq_all"=>0.84, "word_freq_our"=>0.28, "word_freq_over"=>0.84, "word_freq_internet"=>0.84, "word_freq_order"=>0.28, "word_freq_mail"=>0.28, "word_freq_receive"=>0.28, "word_freq_will"=>1.41, "word_freq_business"=>1.41, "word_freq_you"=>0.84, "word_freq_credit"=>1.98, "word_freq_your"=>2.83, "word_freq_000"=>0.28, "word_freq_money"=>0.84, "char_freq_("=>0.128, "char_freq_!"=>1.289, "char_freq_$"=>0.042, "capital_run_length_average"=>3.979, "capital_run_length_longest"=>47.0, "capital_run_length_total"=>386.0, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_mail"=>0.45, "word_freq_you"=>0.45, "word_freq_your"=>1.35, "word_freq_hp"=>1.35, "word_freq_hpl"=>1.35, "word_freq_george"=>1.35, "word_freq_650"=>1.35, "word_freq_lab"=>0.9, "word_freq_labs"=>0.45, "word_freq_telnet"=>0.45, "word_freq_857"=>0.45, "word_freq_415"=>0.45, "word_freq_85"=>1.35, "word_freq_technology"=>0.45, "word_freq_1999"=>0.45, "word_freq_pm"=>0.45, "word_freq_direct"=>0.45, "word_freq_meeting"=>0.45, "word_freq_original"=>0.45, "word_freq_re"=>0.45, "char_freq_("=>0.358, "char_freq_["=>0.43, "char_freq_#"=>0.071, "capital_run_length_average"=>2.236, "capital_run_length_longest"=>12.0, "capital_run_length_total"=>161.0, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_report"=>2.04, "word_freq_technology"=>1.02, "char_freq_("=>0.176, "char_freq_!"=>0.176, "char_freq_$"=>0.352, "capital_run_length_average"=>3.857, "capital_run_length_longest"=>25.0, "capital_run_length_total"=>81.0, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_make"=>0.29, "word_freq_address"=>0.29, "word_freq_our"=>0.29, "word_freq_internet"=>1.46, "word_freq_will"=>0.29, "word_freq_free"=>0.58, "word_freq_business"=>2.04, "word_freq_email"=>0.29, "word_freq_you"=>2.04, "word_freq_credit"=>1.16, "word_freq_your"=>1.46, "char_freq_!"=>0.42, "char_freq_$"=>0.046, "char_freq_#"=>0.046, "capital_run_length_average"=>2.228, "capital_run_length_longest"=>34.0, "capital_run_length_total"=>234.0, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_over"=>1.29, "word_freq_internet"=>0.64, "word_freq_you"=>3.87, "word_freq_your"=>0.64, "char_freq_!"=>1.16, "char_freq_$"=>0.116, "capital_run_length_average"=>1.8, "capital_run_length_longest"=>12.0, "capital_run_length_total"=>63.0, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_address"=>4.16, "word_freq_will"=>4.16, "word_freq_re"=>4.16, "char_freq_!"=>0.709, "capital_run_length_average"=>2.09, "capital_run_length_longest"=>6.0, "capital_run_length_total"=>23.0, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_all"=>0.32, "word_freq_our"=>0.65, "word_freq_over"=>0.65, "word_freq_remove"=>0.32, "word_freq_internet"=>0.32, "word_freq_will"=>0.32, "word_freq_people"=>0.32, "word_freq_free"=>0.32, "word_freq_business"=>0.32, "word_freq_you"=>2.28, "word_freq_your"=>3.25, "word_freq_money"=>0.32, "word_freq_re"=>0.65, "char_freq_("=>0.111, "char_freq_$"=>0.166, "capital_run_length_average"=>1.494, "capital_run_length_longest"=>10.0, "capital_run_length_total"=>139.0, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_you"=>4.16, "char_freq_!"=>0.74, "capital_run_length_average"=>1 ...
# {"bias"=>0.8995944084089785}

# %% [markdown]
# ## Question 4.1 (Continued)
# We can correct this by _normalizing_ the data. A popular normalization is the z-score. For each feature, except bias, and considering only the non-zero values create a new zspambase dataset, ```zspambase```. The dataset ```zspambase``` is identical to spambase except that its features have been normalized as follows:
#
# ### $x_z = \frac{x - \mu}{\sigma}$
#
# where $\mu$ is the mean of the $x$ value and $\sigma$ is the standard deviation. Note that you have already seen an implementation of ```mean``` and ```stdev```, so find it and add it here.

# %%
## Add mean and stdev here

# BEGIN YOUR CODE
#raise NotImplementedError.new()
#END YOUR CODE

# %%
def create_zspambase spambase
  zspambase = spambase.clone
  zspambase["data"] = spambase["data"].collect do |r|
    u = r.clone
    u["features"] = r["features"].clone
    u
  end

  sums=Hash.new {|h,k| h[k] = 0.0}
  mean=Hash.new {|h,k| h[k] = 0.0}
  sigma=Hash.new {|h,k| h[k] = 0.0}
  total=Hash.new {|h,k| h[k] = 0.0}
  size=(zspambase["data"].size).to_f

  zspambase["data"].each do |item|
    item["features"].each do |key,array|
      sums[key]=array+sums[key]
      total[key]=total[key]+1
    end
  end
  
  sums.each do |key,item|
    mean[key]=item.to_f/(total[key].to_f)
  end

  zspambase["data"].each do |item|
    item["features"].each do |key,array|
      sigma[key]=(array.to_f-mean[key].to_f)**2+sigma[key].to_f
    end
  end
  
  sigma.each do |key,item|
    sigma[key]=(sigma[key].to_f/(total[key].to_f-1.0))**0.5
  end
  
  
  zspambase["data"].each do |item|
    item["features"].each do |key,array|
      if key=="bias"
        next
      else
        item["features"][key]=(array.to_f-mean[key].to_f)/sigma[key].to_f
      end
    end
  end

  return zspambase
end

zspambase = create_zspambase spambase
zspambase["data"].first
# Out:
# {"features"=>{"word_freq_our"=>-0.628106690674003, "word_freq_mail"=>-0.0163998685249916, "word_freq_you"=>-1.2509960473524198, "word_freq_your"=>-0.9962817981732773, "word_freq_font"=>0.8660048920660688, "char_freq_["=>-0.19095268670254528, "char_freq_$"=>-0.162631899108401, "char_freq_#"=>-0.038069985077358884, "capital_run_length_average"=>0.06686163123580875, "capital_run_length_longest"=>0.24027347134946417, "capital_run_length_total"=>0.533869650358239, "bias"=>1.0}, "label"=>1.0}

# %%
### TEST ###
t41_zs = create_zspambase spambase

assert_in_delta 0.27, spambase["data"].first["features"]["word_freq_our"], 1e-5
assert_in_delta -0.628106690674003, zspambase["data"].first["features"]["word_freq_our"], 1e-5

assert_in_delta 607.0, spambase["data"].first["features"]["capital_run_length_total"], 1e-5
assert_in_delta 0.53386, zspambase["data"].first["features"]["capital_run_length_total"], 1e-5

# %% [markdown]
# ## Question 4.2 (7 points)
#
# Train Linear Regression for the ```zspambase``` dataset. Tune the learning rate as needed to train in one epoch. Hint: Learning rate may need to be very small.

# %%
def train_zspambase_sgd(obj, w, dataset)
  i = 0
  iters = []
  losses = []
  lr=0.3
  #Define sgd = StochasticGradientDescent.new obj, w, lr
  # You set the learning rate, lr
  
  sgd = StochasticGradientDescent.new obj, w, lr
  model = LinearRegressionModel.new
  
  for i in 0..20 do
    batch_of_examples=[]
    batch_of_examples=dataset["data"][(i*200)...((i+1)*200)]
    sgd.update(batch_of_examples)
    gradient=model.grad(batch_of_examples,w)
    losses << model.func(batch_of_examples,w)

    iters << i
  end

  return [sgd, iters, losses]
end
# Out:
# :train_zspambase_sgd

# %%
### TEST ###
t25_model = LinearRegressionModel.new
t25_w = Hash.new {|h,k| h[k] = 0.0}
t25_w["bias"] = 1
#puts zspambase
t25_trainer, t25_iter, t25_losses = train_zspambase_sgd t25_model, t25_w, zspambase

t25_cum_loss = 0.0
t25_losses.each_index {|i| t25_cum_loss += t25_losses[i]; t25_losses[i] = t25_cum_loss / (t25_iter[i] + 1)}
puts t25_losses
assert_true (t25_losses.last < 0.15), "Expected last loss value less than target"
Daru::DataFrame.new({x: t25_iter, y: t25_losses}).plot(type: :line, x: :x, y: :y) do |plot, diagram|
  plot.x_label "Batches"
  plot.y_label "Cumulative Loss"
end
# Out:
# [{"features"=>{"word_freq_our"=>-0.628106690674003, "word_freq_mail"=>-0.0163998685249916, "word_freq_you"=>-1.2509960473524198, "word_freq_your"=>-0.9962817981732773, "word_freq_font"=>0.8660048920660688, "char_freq_["=>-0.19095268670254528, "char_freq_$"=>-0.162631899108401, "char_freq_#"=>-0.038069985077358884, "capital_run_length_average"=>0.06686163123580875, "capital_run_length_longest"=>0.24027347134946417, "capital_run_length_total"=>0.533869650358239, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_your"=>-0.5011445030101562, "word_freq_george"=>-0.513219991761838, "word_freq_data"=>-0.13195836609207054, "char_freq_["=>-0.02624480502746512, "capital_run_length_average"=>-0.05419307752787099, "capital_run_length_longest"=>-0.12403215198752414, "capital_run_length_total"=>-0.2610535928326181, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_make"=>1.6172689447705917, "word_freq_you"=>-0.661182454089374, "word_freq_your"=>-0.2182089057740871, "char_freq_!"=>-0.33760904627320754, "capital_run_length_average"=>-0.12352928145395675, "capital_run_length_longest"=>-0.25230877992308337, "capital_run_length_total"=>-0.44411682933507685, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_will"=>0.6300079672971014, "word_freq_business"=>-0.35754097868349544, "word_freq_you"=>-0.9173641158096868, "word_freq_hp"=>-0.38567173137329636, "word_freq_lab"=>-0.22769097883405917, "word_freq_meeting"=>-0.6155134201387836, "char_freq_("=>-0.30380620727911045, "char_freq_$"=>-0.4567293370595659, "capital_run_length_average"=>-0.10676252668637602, "capital_run_length_longest"=>-0.2369155845708163, "capital_run_length_total"=>-0.345163728522937, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_our"=>-0.5256644416362517, "word_freq_over"=>-0.18606382202355404, "word_freq_internet"=>-0.29065959465924, "word_freq_order"=>-0.3727959860747348, "word_freq_mail"=>-0.49703854406060294, "word_freq_will"=>-0.7500800420205911, "word_freq_business"=>0.06426457237161551, "word_freq_you"=>0.33971334053882485, "word_freq_your"=>1.9666826506600028, "word_freq_money"=>-0.2379885423021857, "word_freq_project"=>-0.3636900395826446, "char_freq_!"=>0.09549123178969555, "char_freq_$"=>-0.3324985227526083, "capital_run_length_average"=>-0.1153980357208067, "capital_run_length_longest"=>-0.2009981287488597, "capital_run_length_total"=>-0.343514510176068, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_our"=>-0.43460466471380615, "word_freq_lab"=>0.06747494193394707, "word_freq_1999"=>-0.44306350461326677, "word_freq_meeting"=>-0.6020899054120424, "capital_run_length_average"=>-0.04067251776228427, "capital_run_length_longest"=>-0.09837682640041229, "capital_run_length_total"=>0.1891830158626184, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_will"=>-0.7922201339081542, "word_freq_email"=>-0.583301777566667, "word_freq_you"=>-0.6492670279628479, "word_freq_your"=>-0.9569851874460455, "word_freq_hp"=>0.779081577294766, "word_freq_hpl"=>1.249747001904256, "word_freq_george"=>-0.5047279289785196, "word_freq_650"=>-0.2290678389367161, "word_freq_lab"=>-0.3376547532378261, "word_freq_labs"=>-0.6471029454370575, "word_freq_telnet"=>-0.55225840940105, "word_freq_857"=>-0.6302362719935841, "word_freq_415"=>-0.6103078634164378, "word_freq_85"=>-0.2686200918693935, "word_freq_technology"=>-0.492263275356653, "word_freq_1999"=>-0.6091622287575524, "word_freq_direct"=>-0.3662305251648528, "word_freq_original"=>-0.43315921088381704, "word_freq_re"=>-0.05812070888255375, "char_freq_;"=>0.07137939561815754, "char_freq_("=>-0.07738838072219165, "char_freq_["=>-0.1463443020822111, "char_freq_!"=>-0.45249459371726186, "char_freq_#"=>-0.1608244224036431, "capital_run_length_average"=>-0.09245405551253832, "capital_run_length_longest"=>-0.19073599851401496, "capital_run_length_total"=>-0.15055596359239518, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_make"=>-0.33594859850933007, "word_freq_address"=>-0.32736736073368067, "word_freq_all"=>-0.006740 ...
# [{"features"=>{"word_freq_our"=>-0.628106690674003, "word_freq_mail"=>-0.0163998685249916, "word_freq_you"=>-1.2509960473524198, "word_freq_your"=>-0.9962817981732773, "word_freq_font"=>0.8660048920660688, "char_freq_["=>-0.19095268670254528, "char_freq_$"=>-0.162631899108401, "char_freq_#"=>-0.038069985077358884, "capital_run_length_average"=>0.06686163123580875, "capital_run_length_longest"=>0.24027347134946417, "capital_run_length_total"=>0.533869650358239, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_your"=>-0.5011445030101562, "word_freq_george"=>-0.513219991761838, "word_freq_data"=>-0.13195836609207054, "char_freq_["=>-0.02624480502746512, "capital_run_length_average"=>-0.05419307752787099, "capital_run_length_longest"=>-0.12403215198752414, "capital_run_length_total"=>-0.2610535928326181, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_make"=>1.6172689447705917, "word_freq_you"=>-0.661182454089374, "word_freq_your"=>-0.2182089057740871, "char_freq_!"=>-0.33760904627320754, "capital_run_length_average"=>-0.12352928145395675, "capital_run_length_longest"=>-0.25230877992308337, "capital_run_length_total"=>-0.44411682933507685, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_will"=>0.6300079672971014, "word_freq_business"=>-0.35754097868349544, "word_freq_you"=>-0.9173641158096868, "word_freq_hp"=>-0.38567173137329636, "word_freq_lab"=>-0.22769097883405917, "word_freq_meeting"=>-0.6155134201387836, "char_freq_("=>-0.30380620727911045, "char_freq_$"=>-0.4567293370595659, "capital_run_length_average"=>-0.10676252668637602, "capital_run_length_longest"=>-0.2369155845708163, "capital_run_length_total"=>-0.345163728522937, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_our"=>-0.5256644416362517, "word_freq_over"=>-0.18606382202355404, "word_freq_internet"=>-0.29065959465924, "word_freq_order"=>-0.3727959860747348, "word_freq_mail"=>-0.49703854406060294, "word_freq_will"=>-0.7500800420205911, "word_freq_business"=>0.06426457237161551, "word_freq_you"=>0.33971334053882485, "word_freq_your"=>1.9666826506600028, "word_freq_money"=>-0.2379885423021857, "word_freq_project"=>-0.3636900395826446, "char_freq_!"=>0.09549123178969555, "char_freq_$"=>-0.3324985227526083, "capital_run_length_average"=>-0.1153980357208067, "capital_run_length_longest"=>-0.2009981287488597, "capital_run_length_total"=>-0.343514510176068, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_our"=>-0.43460466471380615, "word_freq_lab"=>0.06747494193394707, "word_freq_1999"=>-0.44306350461326677, "word_freq_meeting"=>-0.6020899054120424, "capital_run_length_average"=>-0.04067251776228427, "capital_run_length_longest"=>-0.09837682640041229, "capital_run_length_total"=>0.1891830158626184, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_will"=>-0.7922201339081542, "word_freq_email"=>-0.583301777566667, "word_freq_you"=>-0.6492670279628479, "word_freq_your"=>-0.9569851874460455, "word_freq_hp"=>0.779081577294766, "word_freq_hpl"=>1.249747001904256, "word_freq_george"=>-0.5047279289785196, "word_freq_650"=>-0.2290678389367161, "word_freq_lab"=>-0.3376547532378261, "word_freq_labs"=>-0.6471029454370575, "word_freq_telnet"=>-0.55225840940105, "word_freq_857"=>-0.6302362719935841, "word_freq_415"=>-0.6103078634164378, "word_freq_85"=>-0.2686200918693935, "word_freq_technology"=>-0.492263275356653, "word_freq_1999"=>-0.6091622287575524, "word_freq_direct"=>-0.3662305251648528, "word_freq_original"=>-0.43315921088381704, "word_freq_re"=>-0.05812070888255375, "char_freq_;"=>0.07137939561815754, "char_freq_("=>-0.07738838072219165, "char_freq_["=>-0.1463443020822111, "char_freq_!"=>-0.45249459371726186, "char_freq_#"=>-0.1608244224036431, "capital_run_length_average"=>-0.09245405551253832, "capital_run_length_longest"=>-0.19073599851401496, "capital_run_length_total"=>-0.15055596359239518, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_make"=>-0.33594859850933007, "word_freq_address"=>-0.32736736073368067, "word_freq_all"=>-0.006740 ...
# [{"features"=>{"word_freq_make"=>1.4763151014411129, "word_freq_mail"=>0.35174890422568944, "word_freq_you"=>-0.7028864455322157, "word_freq_hp"=>-0.4073080157448393, "word_freq_hpl"=>-0.19579005054041887, "word_freq_650"=>0.9300404608195563, "char_freq_("=>0.5169584139897204, "capital_run_length_average"=>-0.06623236384594589, "capital_run_length_longest"=>-0.21126025898370443, "capital_run_length_total"=>-0.35505903860415094, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_make"=>-0.6178562851682878, "word_freq_address"=>-0.36005313902352337, "word_freq_our"=>-0.5939592743280859, "word_freq_over"=>-0.6644256997480834, "word_freq_internet"=>-0.3671701385840233, "word_freq_will"=>-0.49723949069521234, "word_freq_you"=>-0.1845654090283269, "word_freq_your"=>-0.5404411137373881, "word_freq_000"=>-0.9769477678922377, "word_freq_hp"=>-0.764306707875298, "word_freq_data"=>-0.5512467170122602, "word_freq_85"=>-0.6342418835805123, "word_freq_1999"=>-0.567637547721481, "word_freq_project"=>-0.5131559412792823, "char_freq_;"=>-0.27518206280335583, "char_freq_("=>-0.005060463905398058, "char_freq_!"=>-0.43334700247658614, "capital_run_length_average"=>-0.09409291124170036, "capital_run_length_longest"=>-0.016279784521654354, "capital_run_length_total"=>1.2248921376963493, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_make"=>-0.15472222851428574, "word_freq_all"=>2.074571040292576, "word_freq_our"=>0.36216838335759277, "word_freq_order"=>-0.3304552136333933, "word_freq_mail"=>-0.47658583446334285, "word_freq_you"=>-1.185461203656526, "word_freq_credit"=>-0.11803174071701095, "word_freq_hp"=>-0.6993978547606692, "char_freq_!"=>0.4191767027630231, "char_freq_$"=>-0.48208256446914916, "capital_run_length_average"=>9.133736403455735, "capital_run_length_longest"=>5.771561667930779, "capital_run_length_total"=>1.478871763114175, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_all"=>-0.9962169832843573, "word_freq_mail"=>-0.7629237688249837, "word_freq_receive"=>-0.7808513106221122, "word_freq_will"=>-0.11797866370714415, "word_freq_people"=>-0.7696750078435894, "word_freq_hp"=>0.4329010273500787, "word_freq_hpl"=>-0.872028414130417, "word_freq_data"=>-0.2351678063185788, "word_freq_technology"=>-0.744864242711895, "word_freq_1999"=>-0.761419392556481, "word_freq_parts"=>-0.42606942592332153, "char_freq_;"=>-0.382235078755551, "char_freq_("=>-0.3729894320603912, "capital_run_length_average"=>-0.09415594415436042, "capital_run_length_longest"=>-0.14455641245721362, "capital_run_length_total"=>0.3508064138557802, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_our"=>-0.44598713682911184, "word_freq_will"=>-0.6763348812173557, "word_freq_you"=>-0.10711513920590682, "word_freq_george"=>-0.5797411502311648, "word_freq_data"=>-0.15131013613454086, "char_freq_;"=>-0.2642953154183868, "char_freq_("=>-0.244057058604368, "capital_run_length_average"=>-0.12847736509777288, "capital_run_length_longest"=>-0.25743984504050577, "capital_run_length_total"=>-0.4193785541320419, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_all"=>0.06149889150325309, "word_freq_our"=>-0.11589544548524655, "word_freq_remove"=>0.09508644098051007, "word_freq_people"=>0.40210677773815207, "word_freq_you"=>-0.5479859058873754, "word_freq_your"=>-0.06888178501060618, "word_freq_money"=>0.13433906541470925, "char_freq_("=>0.40374950071126087, "char_freq_!"=>0.16478727627976, "char_freq_$"=>-0.32489255452973337, "capital_run_length_average"=>0.081611332798267, "capital_run_length_longest"=>-0.10350789151783465, "capital_run_length_total"=>-0.056550517820862296, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_our"=>2.581750445842204, "word_freq_remove"=>0.5231550920529301, "word_freq_internet"=>0.5637081458341733, "word_freq_mail"=>0.18812722744760904, "word_freq_will"=>-0.044233502903908595, "word_freq_free"=>0.8235010572382848, "word_freq_you"=>-0.1845654090283269, "word_freq_your"=>-0.3989733151193535, "word_freq_re"=>-0.016244776919359098, "c ...
# [{"features"=>{"word_freq_make"=>1.4763151014411129, "word_freq_mail"=>0.35174890422568944, "word_freq_you"=>-0.7028864455322157, "word_freq_hp"=>-0.4073080157448393, "word_freq_hpl"=>-0.19579005054041887, "word_freq_650"=>0.9300404608195563, "char_freq_("=>0.5169584139897204, "capital_run_length_average"=>-0.06623236384594589, "capital_run_length_longest"=>-0.21126025898370443, "capital_run_length_total"=>-0.35505903860415094, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_make"=>-0.6178562851682878, "word_freq_address"=>-0.36005313902352337, "word_freq_our"=>-0.5939592743280859, "word_freq_over"=>-0.6644256997480834, "word_freq_internet"=>-0.3671701385840233, "word_freq_will"=>-0.49723949069521234, "word_freq_you"=>-0.1845654090283269, "word_freq_your"=>-0.5404411137373881, "word_freq_000"=>-0.9769477678922377, "word_freq_hp"=>-0.764306707875298, "word_freq_data"=>-0.5512467170122602, "word_freq_85"=>-0.6342418835805123, "word_freq_1999"=>-0.567637547721481, "word_freq_project"=>-0.5131559412792823, "char_freq_;"=>-0.27518206280335583, "char_freq_("=>-0.005060463905398058, "char_freq_!"=>-0.43334700247658614, "capital_run_length_average"=>-0.09409291124170036, "capital_run_length_longest"=>-0.016279784521654354, "capital_run_length_total"=>1.2248921376963493, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_make"=>-0.15472222851428574, "word_freq_all"=>2.074571040292576, "word_freq_our"=>0.36216838335759277, "word_freq_order"=>-0.3304552136333933, "word_freq_mail"=>-0.47658583446334285, "word_freq_you"=>-1.185461203656526, "word_freq_credit"=>-0.11803174071701095, "word_freq_hp"=>-0.6993978547606692, "char_freq_!"=>0.4191767027630231, "char_freq_$"=>-0.48208256446914916, "capital_run_length_average"=>9.133736403455735, "capital_run_length_longest"=>5.771561667930779, "capital_run_length_total"=>1.478871763114175, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_all"=>-0.9962169832843573, "word_freq_mail"=>-0.7629237688249837, "word_freq_receive"=>-0.7808513106221122, "word_freq_will"=>-0.11797866370714415, "word_freq_people"=>-0.7696750078435894, "word_freq_hp"=>0.4329010273500787, "word_freq_hpl"=>-0.872028414130417, "word_freq_data"=>-0.2351678063185788, "word_freq_technology"=>-0.744864242711895, "word_freq_1999"=>-0.761419392556481, "word_freq_parts"=>-0.42606942592332153, "char_freq_;"=>-0.382235078755551, "char_freq_("=>-0.3729894320603912, "capital_run_length_average"=>-0.09415594415436042, "capital_run_length_longest"=>-0.14455641245721362, "capital_run_length_total"=>0.3508064138557802, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_our"=>-0.44598713682911184, "word_freq_will"=>-0.6763348812173557, "word_freq_you"=>-0.10711513920590682, "word_freq_george"=>-0.5797411502311648, "word_freq_data"=>-0.15131013613454086, "char_freq_;"=>-0.2642953154183868, "char_freq_("=>-0.244057058604368, "capital_run_length_average"=>-0.12847736509777288, "capital_run_length_longest"=>-0.25743984504050577, "capital_run_length_total"=>-0.4193785541320419, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_all"=>0.06149889150325309, "word_freq_our"=>-0.11589544548524655, "word_freq_remove"=>0.09508644098051007, "word_freq_people"=>0.40210677773815207, "word_freq_you"=>-0.5479859058873754, "word_freq_your"=>-0.06888178501060618, "word_freq_money"=>0.13433906541470925, "char_freq_("=>0.40374950071126087, "char_freq_!"=>0.16478727627976, "char_freq_$"=>-0.32489255452973337, "capital_run_length_average"=>0.081611332798267, "capital_run_length_longest"=>-0.10350789151783465, "capital_run_length_total"=>-0.056550517820862296, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_our"=>2.581750445842204, "word_freq_remove"=>0.5231550920529301, "word_freq_internet"=>0.5637081458341733, "word_freq_mail"=>0.18812722744760904, "word_freq_will"=>-0.044233502903908595, "word_freq_free"=>0.8235010572382848, "word_freq_you"=>-0.1845654090283269, "word_freq_your"=>-0.3989733151193535, "word_freq_re"=>-0.016244776919359098, "c ...
# [{"features"=>{"word_freq_address"=>-0.23294177900746832, "word_freq_all"=>-0.3991193120332868, "word_freq_our"=>-0.4232221925985004, "word_freq_will"=>-0.6552648352735742, "word_freq_free"=>-0.342174954531144, "word_freq_email"=>0.1065228330684165, "word_freq_you"=>-0.6016053234567431, "word_freq_your"=>-0.13961568431962337, "char_freq_!"=>0.8686892018893624, "capital_run_length_average"=>-0.07609701467724808, "capital_run_length_longest"=>0.04529299688741409, "capital_run_length_total"=>-0.1373622168174432, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_george"=>2.1900866609278276, "capital_run_length_average"=>-0.13210175757572737, "capital_run_length_longest"=>-0.26257091015792816, "capital_run_length_total"=>-0.45895979445689783, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_address"=>-0.22931002586415244, "word_freq_all"=>-0.38205937856897054, "word_freq_our"=>0.658112658355541, "word_freq_remove"=>-0.2639388792737775, "word_freq_internet"=>1.622104003460342, "word_freq_mail"=>0.08586367946130878, "word_freq_receive"=>0.19445815119921192, "word_freq_free"=>0.6786965837265546, "word_freq_you"=>-0.8577869851770559, "word_freq_credit"=>-0.3280126836429381, "word_freq_your"=>-0.10817839573783805, "word_freq_money"=>-0.1345642068252704, "word_freq_1999"=>0.8857262885410184, "word_freq_direct"=>-0.21476098097576354, "char_freq_("=>-0.5176452656939783, "char_freq_!"=>0.020724446945152224, "char_freq_$"=>-0.08910753962060977, "capital_run_length_average"=>-0.017697021097685846, "capital_run_length_longest"=>0.060686192239681205, "capital_run_length_total"=>-0.11592237830814622, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_will"=>0.5773328524376478, "word_freq_technology"=>0.07034797011638615, "capital_run_length_average"=>-0.11388524581696483, "capital_run_length_longest"=>-0.24204664968823866, "capital_run_length_total"=>-0.36825278537910294, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_address"=>-0.214783013290889, "word_freq_our"=>0.4873755766259556, "word_freq_internet"=>-0.43092892518800935, "word_freq_mail"=>-0.09821070691403179, "word_freq_receive"=>-0.3744723681965606, "word_freq_will"=>-0.3392141461168506, "word_freq_free"=>-0.4869794280428743, "word_freq_you"=>-0.2143539743446425, "word_freq_your"=>0.17475720149823123, "word_freq_data"=>0.09381228440341621, "word_freq_parts"=>-0.32491449928820804, "word_freq_project"=>-0.41672632728145154, "word_freq_re"=>-0.482862304509242, "char_freq_("=>-0.04279676833155123, "char_freq_["=>-0.18065844409785278, "char_freq_!"=>-0.4716421849579375, "capital_run_length_average"=>0.009722295909448078, "capital_run_length_longest"=>0.31723944811079974, "capital_run_length_total"=>0.54871261548006, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_all"=>1.5286531694344547, "word_freq_our"=>0.25972613431984165, "word_freq_hp"=>-0.45779267927843953, "word_freq_labs"=>1.0340550471477796, "word_freq_85"=>0.43277681467846696, "word_freq_1999"=>-0.33233102185040964, "char_freq_("=>-0.08367776479321717, "capital_run_length_average"=>-0.10751892163829695, "capital_run_length_longest"=>-0.2317845194533939, "capital_run_length_total"=>-0.34681294686980596, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_will"=>0.4403775538030674, "word_freq_hp"=>-0.032279086638094825, "word_freq_hpl"=>-0.47497102633445476, "word_freq_labs"=>-0.25264129354564324, "word_freq_1999"=>1.0103003316492327, "word_freq_pm"=>0.45442940212238303, "capital_run_length_average"=>-0.037552388585610406, "capital_run_length_longest"=>-0.036804044991343834, "capital_run_length_total"=>-0.23631531762958308, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_all"=>-0.45029911242623577, "word_freq_our"=>-0.4573696089444175, "word_freq_over"=>-0.6872048367825847, "word_freq_will"=>0.514122714606303, "word_freq_people"=>-0.694076182967348, "word_freq_business"=>-0.5288994837996343, "word_freq_you"=>-1.32844631717484, "word_freq_your"=>-1.0984529860640802, "word_freq_hp"=>0.28865913153979234,  ...
# [{"features"=>{"word_freq_address"=>-0.23294177900746832, "word_freq_all"=>-0.3991193120332868, "word_freq_our"=>-0.4232221925985004, "word_freq_will"=>-0.6552648352735742, "word_freq_free"=>-0.342174954531144, "word_freq_email"=>0.1065228330684165, "word_freq_you"=>-0.6016053234567431, "word_freq_your"=>-0.13961568431962337, "char_freq_!"=>0.8686892018893624, "capital_run_length_average"=>-0.07609701467724808, "capital_run_length_longest"=>0.04529299688741409, "capital_run_length_total"=>-0.1373622168174432, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_george"=>2.1900866609278276, "capital_run_length_average"=>-0.13210175757572737, "capital_run_length_longest"=>-0.26257091015792816, "capital_run_length_total"=>-0.45895979445689783, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_address"=>-0.22931002586415244, "word_freq_all"=>-0.38205937856897054, "word_freq_our"=>0.658112658355541, "word_freq_remove"=>-0.2639388792737775, "word_freq_internet"=>1.622104003460342, "word_freq_mail"=>0.08586367946130878, "word_freq_receive"=>0.19445815119921192, "word_freq_free"=>0.6786965837265546, "word_freq_you"=>-0.8577869851770559, "word_freq_credit"=>-0.3280126836429381, "word_freq_your"=>-0.10817839573783805, "word_freq_money"=>-0.1345642068252704, "word_freq_1999"=>0.8857262885410184, "word_freq_direct"=>-0.21476098097576354, "char_freq_("=>-0.5176452656939783, "char_freq_!"=>0.020724446945152224, "char_freq_$"=>-0.08910753962060977, "capital_run_length_average"=>-0.017697021097685846, "capital_run_length_longest"=>0.060686192239681205, "capital_run_length_total"=>-0.11592237830814622, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_will"=>0.5773328524376478, "word_freq_technology"=>0.07034797011638615, "capital_run_length_average"=>-0.11388524581696483, "capital_run_length_longest"=>-0.24204664968823866, "capital_run_length_total"=>-0.36825278537910294, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_address"=>-0.214783013290889, "word_freq_our"=>0.4873755766259556, "word_freq_internet"=>-0.43092892518800935, "word_freq_mail"=>-0.09821070691403179, "word_freq_receive"=>-0.3744723681965606, "word_freq_will"=>-0.3392141461168506, "word_freq_free"=>-0.4869794280428743, "word_freq_you"=>-0.2143539743446425, "word_freq_your"=>0.17475720149823123, "word_freq_data"=>0.09381228440341621, "word_freq_parts"=>-0.32491449928820804, "word_freq_project"=>-0.41672632728145154, "word_freq_re"=>-0.482862304509242, "char_freq_("=>-0.04279676833155123, "char_freq_["=>-0.18065844409785278, "char_freq_!"=>-0.4716421849579375, "capital_run_length_average"=>0.009722295909448078, "capital_run_length_longest"=>0.31723944811079974, "capital_run_length_total"=>0.54871261548006, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_all"=>1.5286531694344547, "word_freq_our"=>0.25972613431984165, "word_freq_hp"=>-0.45779267927843953, "word_freq_labs"=>1.0340550471477796, "word_freq_85"=>0.43277681467846696, "word_freq_1999"=>-0.33233102185040964, "char_freq_("=>-0.08367776479321717, "capital_run_length_average"=>-0.10751892163829695, "capital_run_length_longest"=>-0.2317845194533939, "capital_run_length_total"=>-0.34681294686980596, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_will"=>0.4403775538030674, "word_freq_hp"=>-0.032279086638094825, "word_freq_hpl"=>-0.47497102633445476, "word_freq_labs"=>-0.25264129354564324, "word_freq_1999"=>1.0103003316492327, "word_freq_pm"=>0.45442940212238303, "capital_run_length_average"=>-0.037552388585610406, "capital_run_length_longest"=>-0.036804044991343834, "capital_run_length_total"=>-0.23631531762958308, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_all"=>-0.45029911242623577, "word_freq_our"=>-0.4573696089444175, "word_freq_over"=>-0.6872048367825847, "word_freq_will"=>0.514122714606303, "word_freq_people"=>-0.694076182967348, "word_freq_business"=>-0.5288994837996343, "word_freq_you"=>-1.32844631717484, "word_freq_your"=>-1.0984529860640802, "word_freq_hp"=>0.28865913153979234,  ...
# [{"features"=>{"word_freq_make"=>-0.05404091185037228, "word_freq_address"=>-0.24020528529410004, "word_freq_all"=>-0.43323917896191944, "word_freq_our"=>-0.44598713682911184, "word_freq_mail"=>0.4744651618092499, "word_freq_will"=>-0.21279387045416115, "word_freq_people"=>-0.14598470261459795, "word_freq_free"=>1.236193806746716, "word_freq_you"=>-0.3692545139894827, "word_freq_your"=>0.5127080537524249, "char_freq_("=>-0.1088353010773192, "char_freq_!"=>0.3580867688046767, "char_freq_$"=>-0.4617999825414826, "capital_run_length_average"=>-0.09021638711310555, "capital_run_length_longest"=>-0.12403215198752414, "capital_run_length_total"=>-0.09448253979884925, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_over"=>3.276365007220658, "word_freq_you"=>-0.29180424416706263, "word_freq_data"=>0.5001994552952923, "word_freq_1999"=>1.5501211851181609, "capital_run_length_average"=>-0.0533106167506299, "capital_run_length_longest"=>-0.19073599851401496, "capital_run_length_total"=>-0.3863941871946619, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_mail"=>0.56650235499692, "word_freq_george"=>-0.4424528019008519, "word_freq_data"=>0.19057113461576763, "char_freq_("=>-0.049086152402576765, "char_freq_["=>0.24826833109766838, "capital_run_length_average"=>-0.04149194562686528, "capital_run_length_longest"=>-0.12403215198752414, "capital_run_length_total"=>-0.313828579932426, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_all"=>-0.637958380533715, "word_freq_our"=>-0.2183376945229978, "word_freq_over"=>0.4289728779079838, "word_freq_remove"=>-0.47106887172817424, "word_freq_internet"=>-0.35441838126322606, "word_freq_will"=>-0.802755156880045, "word_freq_people"=>-0.3727811772433221, "word_freq_free"=>-0.4435380859893552, "word_freq_business"=>-0.4893552133882176, "word_freq_you"=>0.10736253107156431, "word_freq_your"=>1.2986402682970615, "word_freq_money"=>-0.2897007100406433, "word_freq_re"=>-0.44696864854078944, "char_freq_("=>-0.401291660380006, "char_freq_$"=>-0.22094432215044232, "char_freq_#"=>-0.21011951140868637, "capital_run_length_average"=>-0.11587078256575731, "capital_run_length_longest"=>-0.2163913241011268, "capital_run_length_total"=>-0.2297184442421071, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"capital_run_length_average"=>-0.1268700258249409, "capital_run_length_longest"=>-0.25743984504050577, "capital_run_length_total"=>-0.45566135776315986, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_make"=>-0.2554035451781992, "word_freq_all"=>-0.04086070928264458, "word_freq_our"=>-0.6850190512505315, "word_freq_order"=>-0.203432896309369, "word_freq_mail"=>-0.7526974140263537, "word_freq_will"=>-0.7816851109362634, "word_freq_free"=>-0.26977271777527884, "word_freq_you"=>-0.3632968009262196, "word_freq_your"=>-0.3439580601012289, "word_freq_money"=>-0.38278261196986707, "word_freq_parts"=>-0.41932576414764733, "word_freq_original"=>-0.8035315003203057, "char_freq_("=>-0.19688667807167662, "char_freq_!"=>-0.16528072510712613, "char_freq_$"=>-0.14234931718073443, "char_freq_#"=>-0.18788839283778447, "capital_run_length_average"=>-0.08296760215719658, "capital_run_length_longest"=>0.11712790853132728, "capital_run_length_total"=>0.17434005074079745, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_our"=>6.1786116342788056, "word_freq_remove"=>3.4091663202508578, "word_freq_will"=>2.157586298221265, "word_freq_you"=>2.311716364478907, "capital_run_length_average"=>0.13351893637384124, "capital_run_length_longest"=>0.04016193176999172, "capital_run_length_total"=>-0.35835747529788897, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_our"=>-0.26386758298422064, "word_freq_mail"=>0.3415225494270594, "word_freq_will"=>-0.5077745136671031, "word_freq_you"=>-0.3573390878629565, "word_freq_hp"=>-0.6236708594602689, "word_freq_hpl"=>-0.5680313515991334, "word_freq_650"=>-0.04948767981954715, "word_freq_data"=>-0.3319266565309303, "char_freq_("=>-0.06480961258014059, "char_freq_!"=>-0.4023461404678731 ...
# [{"features"=>{"word_freq_make"=>-0.05404091185037228, "word_freq_address"=>-0.24020528529410004, "word_freq_all"=>-0.43323917896191944, "word_freq_our"=>-0.44598713682911184, "word_freq_mail"=>0.4744651618092499, "word_freq_will"=>-0.21279387045416115, "word_freq_people"=>-0.14598470261459795, "word_freq_free"=>1.236193806746716, "word_freq_you"=>-0.3692545139894827, "word_freq_your"=>0.5127080537524249, "char_freq_("=>-0.1088353010773192, "char_freq_!"=>0.3580867688046767, "char_freq_$"=>-0.4617999825414826, "capital_run_length_average"=>-0.09021638711310555, "capital_run_length_longest"=>-0.12403215198752414, "capital_run_length_total"=>-0.09448253979884925, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_over"=>3.276365007220658, "word_freq_you"=>-0.29180424416706263, "word_freq_data"=>0.5001994552952923, "word_freq_1999"=>1.5501211851181609, "capital_run_length_average"=>-0.0533106167506299, "capital_run_length_longest"=>-0.19073599851401496, "capital_run_length_total"=>-0.3863941871946619, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_mail"=>0.56650235499692, "word_freq_george"=>-0.4424528019008519, "word_freq_data"=>0.19057113461576763, "char_freq_("=>-0.049086152402576765, "char_freq_["=>0.24826833109766838, "capital_run_length_average"=>-0.04149194562686528, "capital_run_length_longest"=>-0.12403215198752414, "capital_run_length_total"=>-0.313828579932426, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_all"=>-0.637958380533715, "word_freq_our"=>-0.2183376945229978, "word_freq_over"=>0.4289728779079838, "word_freq_remove"=>-0.47106887172817424, "word_freq_internet"=>-0.35441838126322606, "word_freq_will"=>-0.802755156880045, "word_freq_people"=>-0.3727811772433221, "word_freq_free"=>-0.4435380859893552, "word_freq_business"=>-0.4893552133882176, "word_freq_you"=>0.10736253107156431, "word_freq_your"=>1.2986402682970615, "word_freq_money"=>-0.2897007100406433, "word_freq_re"=>-0.44696864854078944, "char_freq_("=>-0.401291660380006, "char_freq_$"=>-0.22094432215044232, "char_freq_#"=>-0.21011951140868637, "capital_run_length_average"=>-0.11587078256575731, "capital_run_length_longest"=>-0.2163913241011268, "capital_run_length_total"=>-0.2297184442421071, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"capital_run_length_average"=>-0.1268700258249409, "capital_run_length_longest"=>-0.25743984504050577, "capital_run_length_total"=>-0.45566135776315986, "bias"=>1.0}, "label"=>0.0}, {"features"=>{"word_freq_make"=>-0.2554035451781992, "word_freq_all"=>-0.04086070928264458, "word_freq_our"=>-0.6850190512505315, "word_freq_order"=>-0.203432896309369, "word_freq_mail"=>-0.7526974140263537, "word_freq_will"=>-0.7816851109362634, "word_freq_free"=>-0.26977271777527884, "word_freq_you"=>-0.3632968009262196, "word_freq_your"=>-0.3439580601012289, "word_freq_money"=>-0.38278261196986707, "word_freq_parts"=>-0.41932576414764733, "word_freq_original"=>-0.8035315003203057, "char_freq_("=>-0.19688667807167662, "char_freq_!"=>-0.16528072510712613, "char_freq_$"=>-0.14234931718073443, "char_freq_#"=>-0.18788839283778447, "capital_run_length_average"=>-0.08296760215719658, "capital_run_length_longest"=>0.11712790853132728, "capital_run_length_total"=>0.17434005074079745, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_our"=>6.1786116342788056, "word_freq_remove"=>3.4091663202508578, "word_freq_will"=>2.157586298221265, "word_freq_you"=>2.311716364478907, "capital_run_length_average"=>0.13351893637384124, "capital_run_length_longest"=>0.04016193176999172, "capital_run_length_total"=>-0.35835747529788897, "bias"=>1.0}, "label"=>1.0}, {"features"=>{"word_freq_our"=>-0.26386758298422064, "word_freq_mail"=>0.3415225494270594, "word_freq_will"=>-0.5077745136671031, "word_freq_you"=>-0.3573390878629565, "word_freq_hp"=>-0.6236708594602689, "word_freq_hpl"=>-0.5680313515991334, "word_freq_650"=>-0.04948767981954715, "word_freq_data"=>-0.3319266565309303, "char_freq_("=>-0.06480961258014059, "char_freq_!"=>-0.4023461404678731 ...

# %%
### TEST ###
t25_model = LinearRegressionModel.new
t25_w = Hash.new {|h,k| h[k] = 0.0}
t25_w["bias"] = 1

t25_trainer, t25_iter, t25_losses = train_zspambase_sgd t25_model, t25_w, zspambase
puts t25_w

t25_cum_loss = 0.0
t25_losses.each_index {|i| t25_cum_loss += t25_losses[i]; t25_losses[i] = t25_cum_loss / (t25_iter[i] + 1)}
assert_true (t25_losses.last < 0.15), "Expected last loss value less than target"
Daru::DataFrame.new({x: t25_iter, y: t25_losses}).plot(type: :line, x: :x, y: :y) do |plot, diagram|
  plot.x_label "Batches"
  plot.y_label "Cumulative Loss"
end

# %% [markdown]
# ## Question 4.3 (7 points)
#
# Run logistic regression on the ```zspambase``` dataset, tuning the learning rate.

# %%
def train_zspambase_logistic_sgd(obj, w, dataset)
  i = 0
  iters = []
  losses = []
  
  lr=0.4
  
  sgd = StochasticGradientDescent.new obj, w, lr
  model = LogisticRegressionModel.new

    for i in 0..40 do
      batch_of_examples=[]
      batch_of_examples=dataset["data"][(i*100)...((i+1)*100-1)]
      sgd.update(batch_of_examples)
      losses << model.func(batch_of_examples,w)
      iters << i
    end

  return [sgd, iters, losses]
end

# %%
### TEST ###
t43_model = LogisticRegressionModel.new
t43_w = Hash.new {|h,k| h[k] = 0.0}
t43_w["bias"] = 1

t43_trainer, t43_iter, t43_losses = train_zspambase_logistic_sgd t43_model, t43_w, zspambase
puts "zsp"
puts zspambase["data"]
t43_cum_loss = 0.0
t43_losses.each_index {|i| t43_cum_loss += t43_losses[i]; t43_losses[i] = t43_cum_loss / (t43_iter[i] + 1)}
puts t43_w
puts t43_losses
assert_true(t43_losses.last < 0.6, "Expected last loss value < 0.6")
Daru::DataFrame.new({x: t43_iter, y: t43_losses}).plot(type: :line, x: :x, y: :y) do |plot, diagram|
  plot.x_label "Batches"
  plot.y_label "Cumulative Loss"
end

# %%
### TEST ###
t43_model = LogisticRegressionModel.new
t43_w = Hash.new {|h,k| h[k] = 0.0}
t43_w["bias"] = 1

t43_trainer, t43_iter, t43_losses = train_zspambase_logistic_sgd t43_model, t43_w, zspambase
t43_cum_loss = 0.0
t43_losses.each_index {|i| t43_cum_loss += t43_losses[i]; t43_losses[i] = t43_cum_loss / (t43_iter[i] + 1)}
puts t43_w

assert_true(t43_losses.last < 0.6, "Expected last loss value < 0.6")
Daru::DataFrame.new({x: t43_iter, y: t43_losses}).plot(type: :line, x: :x, y: :y) do |plot, diagram|
  plot.x_label "Batches"
  plot.y_label "Cumulative Loss"
end
